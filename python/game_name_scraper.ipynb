# %%
# Import dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
from splinter import Browser 
import time
import re

# %%
# Scrape wiki site for original xbox titles
url = 'https://en.wikipedia.org/wiki/List_of_Xbox_games'
# Use pandas to read for tables
titles = pd.read_html(url)[0]['Title']
titles
# Out:
#                              Title
# 0            007: Agent Under Fire
# 1       007: Everything or Nothing
# 2       007: From Russia with Love
# 3                   007: Nightfire
# 4                  187 Ride or Die
# ..                             ...
# 990               Yourself!Fitness
# 991  Yu-Gi-Oh! The Dawn of Destiny
# 992     Zapper: One Wicked Cricket
# 993                        Zathura
# 994                      ZillerNet
#
# [995 rows x 1 columns]

# %%
# Scrape wiki site for xbox360 A through L titles
url = 'https://en.wikipedia.org/wiki/List_of_Xbox_360_games_(A%E2%80%93L)'
# Use pandas to read for tables
xbox360AL_titles = pd.read_html(url)[1]['Title']
xbox360AL_titles
# Out:
#                                      Title
# 0                    0 Day Attack on Earth
# 1                              007 Legends
# 2                   007: Quantum of Solace
# 3                            0-D Beat Drop
# 4                                1 vs. 100
# ..                                     ...
# 990                             Lucha Fury
# 991  Lucha Libre AAA 2010: Héroes del Ring
# 992                               Lucidity
# 993                          Lumines Live!
# 994                                Luxor 2
#
# [995 rows x 1 columns]

# %%
# Concat titles
titles = pd.concat([titles, xbox360AL_titles])
titles
# Out:
#                                      Title
# 0                    007: Agent Under Fire
# 1               007: Everything or Nothing
# 2               007: From Russia with Love
# 3                           007: Nightfire
# 4                          187 Ride or Die
# ..                                     ...
# 990                             Lucha Fury
# 991  Lucha Libre AAA 2010: Héroes del Ring
# 992                               Lucidity
# 993                          Lumines Live!
# 994                                Luxor 2
#
# [1990 rows x 1 columns]

# %%
# Scrape wiki site for xbox360 M through Z titles
url = 'https://en.wikipedia.org/wiki/List_of_Xbox_360_games_(M%E2%80%93Z)'
# Use pandas to read for tables
xbox360MZ_titles = pd.read_html(url)[1]['Title']
xbox360MZ_titles
# Out:
#                              Title
# 0                       Mad Riders
# 1                       Mad Tracks
# 2     Madagascar 3: The Video Game
# 3                 Madagascar Kartz
# 4      Madagascar: Escape 2 Africa
# ...                            ...
# 1084                 Zumba Fitness
# 1085            Zumba Fitness Core
# 1086            Zumba Fitness Rush
# 1087    Zumba Fitness: World Party
# 1088                    Zumba Kids
#
# [1089 rows x 1 columns]

# %%
# Concat titles
titles = pd.concat([titles, xbox360MZ_titles])
titles
# Out:
#                            Title
# 0          007: Agent Under Fire
# 1     007: Everything or Nothing
# 2     007: From Russia with Love
# 3                 007: Nightfire
# 4                187 Ride or Die
# ...                          ...
# 1084               Zumba Fitness
# 1085          Zumba Fitness Core
# 1086          Zumba Fitness Rush
# 1087  Zumba Fitness: World Party
# 1088                  Zumba Kids
#
# [3079 rows x 1 columns]

# %%
# Scrape wiki site for xboxOne A through L titles
url = 'https://en.wikipedia.org/wiki/List_of_Xbox_One_games_(A%E2%80%93L)'
# Use pandas to read for tables
xboxOneAL_titles = pd.read_html(url)[1]['Title']
xboxOneAL_titles
# Out:
#                                 Title
# 0                     #killallzombies
# 1                           #Wargames
# 2                 'n Verlore Verstand
# 3                   10 Second Ninja X
# 4                     101 Ways to Die
# ...                               ...
# 1285                    Lovely Planet
# 1286  Lovers in a Dangerous Spacetime
# 1287                           Lumini
# 1288                             Lumo
# 1289               Lumines Remastered
#
# [1290 rows x 1 columns]

# %%
# Concat Titles
titles = pd.concat([titles, xboxOneAL_titles])
titles
# Out:
#                                 Title
# 0               007: Agent Under Fire
# 1          007: Everything or Nothing
# 2          007: From Russia with Love
# 3                      007: Nightfire
# 4                     187 Ride or Die
# ...                               ...
# 1285                    Lovely Planet
# 1286  Lovers in a Dangerous Spacetime
# 1287                           Lumini
# 1288                             Lumo
# 1289               Lumines Remastered
#
# [4369 rows x 1 columns]

# %%
# Scrape wiki site for xboxOne M through Z titles
url = 'https://en.wikipedia.org/wiki/List_of_Xbox_One_games_(M%E2%80%93Z)'
# Use pandas to read for tables
xboxOneMZ_titles = pd.read_html(url)[1]['Title']
xboxOneMZ_titles
# Out:
#                                        Title
# 0                           Mable & the Wood
# 1                                Machinarium
# 2                           Mad Games Tycoon
# 3                              Madden NFL 15
# 4                              Madden NFL 16
# ...                                      ...
# 1274                          Zombie Vikings
# 1275      Zombieland: Double Tap - Road Trip
# 1276                              Zoo Tycoon
# 1277  Zoo Tycoon: Ultimate Animal Collection
# 1278              Zumba Fitness: World Party
#
# [1279 rows x 1 columns]

# %%
# Concat Titles
titles = pd.concat([titles, xboxOneMZ_titles])
titles
# Out:
#                                        Title
# 0                      007: Agent Under Fire
# 1                 007: Everything or Nothing
# 2                 007: From Russia with Love
# 3                             007: Nightfire
# 4                            187 Ride or Die
# ...                                      ...
# 1274                          Zombie Vikings
# 1275      Zombieland: Double Tap - Road Trip
# 1276                              Zoo Tycoon
# 1277  Zoo Tycoon: Ultimate Animal Collection
# 1278              Zumba Fitness: World Party
#
# [5648 rows x 1 columns]

# %%
# Remove Duplicates for Xbox Titles
titles = titles.drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                        Title
# 0                      007: Agent Under Fire
# 1                 007: Everything or Nothing
# 2                 007: From Russia with Love
# 3                             007: Nightfire
# 4                            187 Ride or Die
# ...                                      ...
# 5425                            Zombie Party
# 5426                          Zombie Pinball
# 5427                          Zombie Vikings
# 5428      Zombieland: Double Tap - Road Trip
# 5429  Zoo Tycoon: Ultimate Animal Collection
#
# [5430 rows x 1 columns]

# %%
# Scrape wiki site for original playstation A through L titles
url = 'https://en.wikipedia.org/wiki/List_of_PlayStation_games_(A%E2%80%93L)'
# Use pandas to read for tables
sonyAL_titles = pd.read_html(url)[0]['Title']
sonyAL_titles
# Out:
#                                             Title
# 0                                      007 Racing
# 1                    007: The World Is Not Enough
# 2                        007: Tomorrow Never Dies
# 3                          100 Manyen Quiz Hunter
# 4     101 Dalmatians II: Patch's London Adventure
# ...                                           ...
# 1467               Lunar 2: Eternal Blue Complete
# 1468              Lunar Wing: Toki o Koeta Seisen
# 1469                             Lunatic Dawn III
# 1470                         Lunatic Dawn Odyssey
# 1471      Lupin III: Chateau de Cagliostro Saikai
#
# [1472 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, sonyAL_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                         Title
# 0                       007: Agent Under Fire
# 1                  007: Everything or Nothing
# 2                  007: From Russia with Love
# 3                              007: Nightfire
# 4                             187 Ride or Die
# ...                                       ...
# 6875           Lunar 2: Eternal Blue Complete
# 6876          Lunar Wing: Toki o Koeta Seisen
# 6877                         Lunatic Dawn III
# 6878                     Lunatic Dawn Odyssey
# 6879  Lupin III: Chateau de Cagliostro Saikai
#
# [6880 rows x 1 columns]

# %%
# Scrape wiki site for original playstation M through Z titles
url = 'https://en.wikipedia.org/wiki/List_of_PlayStation_games_(M%E2%80%93Z)'
# Use pandas to read for tables
sonyMZ_titles = pd.read_html(url)[0]['Title']
sonyMZ_titles
# Out:
#                                             Title
# 0                              M&Ms Shell Shocked
# 1               Machine Head•Blam! MachineheadPAL
# 2                                  Machine Hunter
# 3                    Macross Digital Mission VF-X
# 4                  Macross: Do You Remember Love?
# ...                                           ...
# 1609  Zoku Mikagura Shōjo Tanteidan ~Kanketsuhen~
# 1610                                         Zoop
# 1611         Zork I: The Great Underground Empire
# 1612               Zutto Issho: With me Everytime
# 1613                  ZXE-D: Legend of Plasmalite
#
# [1614 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, sonyMZ_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                             Title
# 0                           007: Agent Under Fire
# 1                      007: Everything or Nothing
# 2                      007: From Russia with Love
# 3                                  007: Nightfire
# 4                                 187 Ride or Die
# ...                                           ...
# 8464  Zoku Mikagura Shōjo Tanteidan ~Kanketsuhen~
# 8465                                         Zoop
# 8466         Zork I: The Great Underground Empire
# 8467               Zutto Issho: With me Everytime
# 8468                  ZXE-D: Legend of Plasmalite
#
# [8469 rows x 1 columns]

# %%
# Scrape wiki site for original playstation2 A through K titles
url = 'https://en.wikipedia.org/wiki/List_of_PlayStation_2_games_(A%E2%80%93K)'
# Use pandas to read for tables
sony2AK_titles = pd.DataFrame(pd.read_html(url)[1]['Title'], columns=['Title'])
sony2AK_titles
# Out:
#                                                 Title
# 0                       ¡Qué pasa Neng! El videojuego
# 1                                     .hack//frägment
# 2                           .hack//G.U.vol.1//Rebirth
# 3                         .hack//G.U.vol.2//Reminisce
# 4                        .hack//G.U.vol.3//Redemption
# ...                                               ...
# 2028                                  Kyojin no Hoshi
# 2029  Kyoufu Shinbun (Heisei-Han) Kaiki! Shinrei File
# 2030   Kyoushuu Kidou Butai: Kougeki Helicopter Senki
# 2031                     Kyuuketsu Hime Yui: Senyasyo
# 2032                         Kyuuketsu Kitan Moonties
#
# [2033 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, sony2AK_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                                  Title
# 0                                007: Agent Under Fire
# 1                           007: Everything or Nothing
# 2                           007: From Russia with Love
# 3                                       007: Nightfire
# 4                                      187 Ride or Die
# ...                                                ...
# 10224                                  Kyojin no Hoshi
# 10225  Kyoufu Shinbun (Heisei-Han) Kaiki! Shinrei File
# 10226   Kyoushuu Kidou Butai: Kougeki Helicopter Senki
# 10227                     Kyuuketsu Hime Yui: Senyasyo
# 10228                         Kyuuketsu Kitan Moonties
#
# [10229 rows x 1 columns]

# %%
# Scrape wiki site for original playstation2 L through Z titles
url = 'https://en.wikipedia.org/wiki/List_of_PlayStation_2_games_(L%E2%80%93Z)'
# Use pandas to read for tables
sony2LZ_titles = pd.DataFrame(pd.read_html(url)[1]['Title'], columns=['Title'])
sony2LZ_titles
# Out:
#                                                   Title
# 0                    L no Kisetsu 2: Invisible Memories
# 1                                             L.A. Rush
# 2                                       L2: Love x Loop
# 3      La Corda d'Oro•Kiniro no Corda: La Corda d'OroJP
# 4     La Pucelle: Tactics•La PucelleJP,KO•La Pucelle...
# ...                                                 ...
# 2455    Zone of the Enders•Z.O.E.: Zone of the EndersJP
# 2456  Zone of the Enders: The 2nd Runner•Anubis: Zon...
# 2457                  Zoo Puzzle•SuperLite 2000: ZoooJP
# 2458                                            ZooCube
# 2459                                             Zwei!!
#
# [2460 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, sony2LZ_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                                    Title
# 0                                  007: Agent Under Fire
# 1                             007: Everything or Nothing
# 2                             007: From Russia with Love
# 3                                         007: Nightfire
# 4                                        187 Ride or Die
# ...                                                  ...
# 12236    Zone of the Enders•Z.O.E.: Zone of the EndersJP
# 12237  Zone of the Enders: The 2nd Runner•Anubis: Zon...
# 12238                  Zoo Puzzle•SuperLite 2000: ZoooJP
# 12239                                            ZooCube
# 12240                                             Zwei!!
#
# [12241 rows x 1 columns]

# %%
# Scrape wiki site for playstation3 disc titles
url = 'https://en.wikipedia.org/wiki/List_of_PlayStation_3_games_released_on_disc'
# Use pandas to read for tables
sony3disc_titles = pd.read_html(url)[0]['Title']
sony3disc_titles
# Out:
#                                        Title
# 0          &: Sora no Mukō de Saki Masuyō ni
# 1                              .hack//Versus
# 2                                007 Legends
# 3                     007: Quantum of Solace
# 4           2010 FIFA World Cup South Africa
# ...                                      ...
# 1429                     You Don't Know Jack
# 1430                   Young Justice: Legacy
# 1431       Zone of the Enders: HD Collection
# 1432          Zumba Fitness – Join the Party
# 1433  Z/X – Crusade of the Absolute Boundary
#
# [1434 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, sony3disc_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                         Title
# 0                       007: Agent Under Fire
# 1                  007: Everything or Nothing
# 2                  007: From Russia with Love
# 3                              007: Nightfire
# 4                             187 Ride or Die
# ...                                       ...
# 12876                Yoostar 2: In the Movies
# 12877                           Yorunonaikuni
# 12878       Zone of the Enders: HD Collection
# 12879          Zumba Fitness – Join the Party
# 12880  Z/X – Crusade of the Absolute Boundary
#
# [12881 rows x 1 columns]

# %%
# Scrape wiki site for playstation3 download titles
url = 'https://en.wikipedia.org/wiki/List_of_download-only_PlayStation_3_games'
# Use pandas to read for tables
sony3download_titles = pd.read_html(url)[1]['Title']
sony3download_titles
# Out:
#                                     Title
# 0                         #killallzombies
# 1                             .detuned[1]
# 2                   1942: Joint Strike[2]
# 3                       3 on 3 NHL Arcade
# 4          3D Ultra Minigolf Adventures 2
# ..                                    ...
# 756    Zombie Apocalypse: Never Die Alone
# 757                      Zombie Driver HD
# 758  Zombie Tycoon II: Brainhov's Revenge
# 759                              Zuma [8]
# 760                       Zuma's Revenge!
#
# [761 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, sony3download_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                       Title
# 0                     007: Agent Under Fire
# 1                007: Everything or Nothing
# 2                007: From Russia with Love
# 3                            007: Nightfire
# 4                           187 Ride or Die
# ...                                     ...
# 13326                      Zen Pinball[124]
# 13327                         Zen Pinball 2
# 13328                               Zombeer
# 13329  Zombie Tycoon II: Brainhov's Revenge
# 13330                              Zuma [8]
#
# [13331 rows x 1 columns]

# %%
# Scrape wiki site for playstation4 A through L titles
url = 'https://en.wikipedia.org/wiki/List_of_PlayStation_4_games'
# Use pandas to read for tables
sony4AL_titles = pd.read_html(url)[1]['Title']
sony4AL_titles
# Out:
#                                 Title
# 0                            #Funtime
# 1                     #killallzombies
# 2                   10 Second Ninja X
# 3                    100ft Robot Golf
# 4                     101 Ways to Die
# ...                               ...
# 1440  Lovers in a Dangerous Spacetime
# 1441               Lumines Remastered
# 1442                           Lumini
# 1443                             Lumo
# 1444                             Luna
#
# [1445 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, sony4AL_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                                    Title
# 0                                  007: Agent Under Fire
# 1                             007: Everything or Nothing
# 2                             007: From Russia with Love
# 3                                         007: Nightfire
# 4                                        187 Ride or Die
# ...                                                  ...
# 13970                                    Lost Soul Aside
# 13971                                        Lost Sphear
# 13972                        Lost Words: Beyond the Page
# 13973  Love Live! School Idol Festival: After School ...
# 13974                                               Luna
#
# [13975 rows x 1 columns]

# %%
# Scrape wiki site for playstation4 A through L titles
url = 'https://en.wikipedia.org/wiki/List_of_PlayStation_4_games_(M%E2%80%93Z)'
# Use pandas to read for tables
sony4MZ_titles = pd.read_html(url)[1]['Title']
sony4MZ_titles
# Out:
#                                           Title
# 0                                   Machinarium
# 1                                       Mad Max
# 2                                 Madden NFL 15
# 3                                 Madden NFL 16
# 4                                 Madden NFL 17
# ...                                         ...
# 1429                    Zombie Army 4: Dead War
# 1430            Zombie Driver: Immortal Edition
# 1431                             Zombie Vikings
# 1432  Zone of the Enders: The 2nd Runner – Mars
# 1433                                     Zotrix
#
# [1434 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, sony4MZ_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                            Title
# 0                          007: Agent Under Fire
# 1                     007: Everything or Nothing
# 2                     007: From Russia with Love
# 3                                 007: Nightfire
# 4                                187 Ride or Die
# ...                                          ...
# 14570                                Zero Strain
# 14571                          Zero Time Dilemma
# 14572            Zombie Driver: Immortal Edition
# 14573  Zone of the Enders: The 2nd Runner – Mars
# 14574                                     Zotrix
#
# [14575 rows x 1 columns]

# %%
# Scrape wiki site for SNES titles
url = 'https://en.wikipedia.org/wiki/List_of_Super_Nintendo_Entertainment_System_games'
# Use pandas to read for tables
snes_titles = pd.read_html(url)[0]['Title']
snes_titles
# Out:
#                                    Title
# 0                     3 Ninjas Kick Back
# 1                   3rd Super Robot Wars
# 2                    3×3 Eyes Jūma hōkan
# 3               3×3 Eyes Seima kōrin-den
# 4                            4 Nin Shōgi
# ...                                  ...
# 1752          Zoku: The Legend of Bishin
# 1753  Zombies Ate My Neighbors•ZombiesEU
# 1754                    Zoo-tto Mahjong!
# 1755  Zool: Ninja of the "Nth" Dimension
# 1756                                Zoop
#
# [1757 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, snes_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                           Title
# 0                         007: Agent Under Fire
# 1                    007: Everything or Nothing
# 2                    007: From Russia with Love
# 3                                007: Nightfire
# 4                               187 Ride or Die
# ...                                         ...
# 16242  Zig Zag Cat: Ostrich Club mo Oosawagi da
# 16243                Zoku: The Legend of Bishin
# 16244        Zombies Ate My Neighbors•ZombiesEU
# 16245                          Zoo-tto Mahjong!
# 16246        Zool: Ninja of the "Nth" Dimension
#
# [16247 rows x 1 columns]

# %%
# Scrape wiki site for N64 titles
url = 'https://en.wikipedia.org/wiki/List_of_Nintendo_64_games'
# Use pandas to read for tables
n64_titles = pd.DataFrame(pd.read_html(url)[1]['Title[11][12][13][14]'])
n64_titles.columns = ['Title']
n64_titles
# Out:
#                                                  Title
# 0                                   1080° Snowboarding
# 1    64 de Hakken!! Tamagotchi: Minna de Tamagotchi...
# 2                      64 Hanafuda: Tenshi no Yakusoku
# 3                                             64 Ozumo
# 4                                           64 Ozumo 2
# ..                                                 ...
# 388                              WWF Wrestlemania 2000
# 389  Xena: Warrior Princess - The Talisman of FateX...
# 390                          Yakochu II: Satsujin Koro
# 391                         Yoshi's StoryYoshi StoryJP
# 392                         Zoor: Majū Tsukai Densetsu
#
# [393 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, n64_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                                    Title
# 0                                  007: Agent Under Fire
# 1                             007: Everything or Nothing
# 2                             007: From Russia with Love
# 3                                         007: Nightfire
# 4                                        187 Ride or Die
# ...                                                  ...
# 16554                              WWF Wrestlemania 2000
# 16555  Xena: Warrior Princess - The Talisman of FateX...
# 16556                          Yakochu II: Satsujin Koro
# 16557                         Yoshi's StoryYoshi StoryJP
# 16558                         Zoor: Majū Tsukai Densetsu
#
# [16559 rows x 1 columns]

# %%
# Scrape wiki site for GameCube titles
url = 'https://en.wikipedia.org/wiki/List_of_GameCube_games'
# Use pandas to read for tables
gamecube_titles = pd.read_html(url)[1]['Title[2][3][4][5][6][7][8][9]']
gamecube_titles.columns = ['Title']
gamecube_titles
# Out:
#                                                 Title
# 0                                     1080° Avalanche
# 1                    18 Wheeler: American Pro Trucker
# 2                                 2002 FIFA World Cup
# 3    2006 FIFA World Cup•FIFA World Cup: Germany 2006
# 4                                           4x4 EVO 2
# ..                                                ...
# 653                                         Zoids Vs.
# 654                                     Zoids Vs. III
# 655                             Zoids: Battle Legends
# 656                           Zoids: Full Metal Crash
# 657                                           ZooCube
#
# [658 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, gamecube_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                             Title
# 0           007: Agent Under Fire
# 1      007: Everything or Nothing
# 2      007: From Russia with Love
# 3                  007: Nightfire
# 4                 187 Ride or Die
# ...                           ...
# 16842     Zatch Bell! Mamodo Fury
# 16843                   Zoids Vs.
# 16844               Zoids Vs. III
# 16845       Zoids: Battle Legends
# 16846     Zoids: Full Metal Crash
#
# [16847 rows x 1 columns]

# %%
# Scrape wiki site for Wii titles
url = 'https://en.wikipedia.org/wiki/List_of_Wii_games'
# Use pandas to read for tables
wii_titles = pd.read_html(url)[0]['Title']
wii_titles
# Out:
#                               Title
# 0            The $1,000,000 Pyramid
# 1            007: Quantum of Solace
# 2                10 Minute Solution
# 3            101-in-1 Party Megamix
# 4     101-in-1 Sports Party Megamix
# ...                             ...
# 1541  Zumba Fitness: Join the Party
# 1542                Zumba Fitness 2
# 1543             Zumba Fitness Core
# 1544     Zumba Fitness: World Party
# 1545                     Zumba Kids
#
# [1546 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, wii_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                                    Title
# 0                                  007: Agent Under Fire
# 1                             007: Everything or Nothing
# 2                             007: From Russia with Love
# 3                                         007: Nightfire
# 4                                        187 Ride or Die
# ...                                                  ...
# 17894                         Zero: Tsukihami no KamenJP
# 17895  ZhuZhu Pets: Featuring The Wild Bunch•ZhuZhu P...
# 17896                                       Zoo Hospital
# 17897                      Zumba Fitness: Join the Party
# 17898                                    Zumba Fitness 2
#
# [17899 rows x 1 columns]

# %%
# Scrape wiki site for gameboy titles
url = 'https://en.wikipedia.org/wiki/List_of_Game_Boy_games'
# Use pandas to read for tables
gameboy_titles = pd.read_html(url)[0]['Title']
gameboy_titles
# Out:
#                                                   Title
# 0     3 Choume no Tama: Tama and Friends – 3 Choume ...
# 1                                3-Pun Yosō Umaban Club
# 2                                        4-in-1 Fun Pak
# 3                              4-in-1 Funpak: Volume II
# 4                      99 Nendohan: Eitango Center 1500
# ...                                                 ...
# 1051                           Zen: Intergalactic Ninja
# 1052                            Zettai Muteki Raijin-Oh
# 1053                                     Zoids Densetsu
# 1054                 Zool: Ninja of the "Nth" Dimension
# 1055                                               Zoop
#
# [1056 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, gameboy_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                  Title
# 0                007: Agent Under Fire
# 1           007: Everything or Nothing
# 2           007: From Russia with Love
# 3                       007: Nightfire
# 4                      187 Ride or Die
# ...                                ...
# 18796  Z-Kai Kyuukyoku no Eitango 1500
# 18797     Zen-Nippon Pro Wrestling Jet
# 18798         Zen: Intergalactic Ninja
# 18799          Zettai Muteki Raijin-Oh
# 18800                   Zoids Densetsu
#
# [18801 rows x 1 columns]

# %%
# Scrape wiki site for gameboy color titles
url = 'https://en.wikipedia.org/wiki/List_of_Game_Boy_Color_games'
# Use pandas to read for tables
gameboyColor_titles = pd.DataFrame(pd.read_html(url)[0]['Title[4][5][6][7]'])
gameboyColor_titles.columns = ['Title']
gameboyColor_titles
# Out:
#                                        Title
# 0               007: The World Is Not Enough
# 1                             3D Pocket Pool
# 2               3D Ultra Pinball: Thrillride
# 3                             10 Pin Bowling
# 4                                       1942
# ..                                       ...
# 660                           Zebco Fishing!
# 661              Zidane: Football Generation
# 662        Zoboomafoo: Playtime in Zobooland
# 663  Zoids: Jashin Fukkatsu! Genobreaker Hen
# 664  Zoids: Shirogane no Jukishin Liger Zero
#
# [665 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, gameboyColor_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                          Title
# 0                        007: Agent Under Fire
# 1                   007: Everything or Nothing
# 2                   007: From Russia with Love
# 3                               007: Nightfire
# 4                              187 Ride or Die
# ...                                        ...
# 19305                           Zebco Fishing!
# 19306              Zidane: Football Generation
# 19307        Zoboomafoo: Playtime in Zobooland
# 19308  Zoids: Jashin Fukkatsu! Genobreaker Hen
# 19309  Zoids: Shirogane no Jukishin Liger Zero
#
# [19310 rows x 1 columns]

# %%
# Scrape wiki site for gameboy advance titles
url = 'https://en.wikipedia.org/wiki/List_of_Game_Boy_Advance_games'
# Use pandas to read for tables
gameboyAdvance_titles = pd.DataFrame(pd.read_html(url)[2]['Title(s)[3]'])
gameboyAdvance_titles.columns = ['Title']
gameboyAdvance_titles
# Out:
#                                                   Title
# 0     007: Everything or Nothing•James Bond 007: Eve...
# 1                                        007: Nightfire
# 2     3-in-1 Sports Pack: Paintball Splat! / Dodgeba...
# 3                                    A Sound of Thunder
# 4                                    Ace Combat Advance
# ...                                                 ...
# 1498                                         Zoids Saga
# 1499                                 Zoids Saga: Fuzors
# 1500  Zone of the Enders: The Fist of Mars•Zone of t...
# 1501                                            ZooCube
# 1502  Zooo: Action Puzzle Game•Minna no Soft Series:...
#
# [1503 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, gameboyAdvance_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                                    Title
# 0                                  007: Agent Under Fire
# 1                             007: Everything or Nothing
# 2                             007: From Russia with Love
# 3                                         007: Nightfire
# 4                                        187 Ride or Die
# ...                                                  ...
# 20501                       Zoids Legacy•Zoids Saga IIJP
# 20502                                         Zoids Saga
# 20503                                 Zoids Saga: Fuzors
# 20504  Zone of the Enders: The Fist of Mars•Zone of t...
# 20505  Zooo: Action Puzzle Game•Minna no Soft Series:...
#
# [20506 rows x 1 columns]

# %%
# Scrape wiki site for gameboy advance titles
url = 'https://en.wikipedia.org/wiki/List_of_Nintendo_DS_games'
# Use pandas to read for tables
nDS_titles = pd.DataFrame(pd.read_html(url)[0]['Title'])
nDS_titles
# Out:
#                             Title
# 0          007: Quantum of Solace
# 1                       1 vs. 100
# 2                       1 vs. 100
# 3          100 All-Time Favorites
# 4               100 Classic Books
# ...                           ...
# 2000                Zoo Tycoon DS
# 2001              Zoo Tycoon 2 DS
# 2002  Zoo Vet: Endangered Animals
# 2003                         Zubo
# 2004              Zuma's Revenge!
#
# [2005 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, nDS_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                              Title
# 0            007: Agent Under Fire
# 1       007: Everything or Nothing
# 2       007: From Russia with Love
# 3                   007: Nightfire
# 4                  187 Ride or Die
# ...                            ...
# 22063                   Zoo Keeper
# 22064                Zoo Tycoon DS
# 22065              Zoo Tycoon 2 DS
# 22066  Zoo Vet: Endangered Animals
# 22067                         Zubo
#
# [22068 rows x 1 columns]

# %%
# Scrape wiki site for n3DS titles
url = 'https://en.wikipedia.org/wiki/List_of_Nintendo_3DS_games'
# Use pandas to read for tables
n3DS_titles = pd.DataFrame(pd.read_html(url)[0]['Title'])
n3DS_titles
# Out:
#                                           Title
# 0                    10-in-1: Arcade Collection
# 1     100% Pascal Sensei: Kanpeki Paint Bombers
# 2                          1000m Zombie Escape!
# 3                                   1001 Spikes
# 4                               101 DinoPets 3D
# ...                                         ...
# 1340  Zeus Quest Remastered Anagenissis of Gaia
# 1341                                 Zig Zag Go
# 1342                            Zombie Incident
# 1343                         Zombie Slayer Diox
# 1344                              Zoo Resort 3D
#
# [1345 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, n3DS_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                            Title
# 0                          007: Agent Under Fire
# 1                     007: Everything or Nothing
# 2                     007: From Russia with Love
# 3                                 007: Nightfire
# 4                                187 Ride or Die
# ...                                          ...
# 23244  Zeus Quest Remastered Anagenissis of Gaia
# 23245                                 Zig Zag Go
# 23246                            Zombie Incident
# 23247                         Zombie Slayer Diox
# 23248                              Zoo Resort 3D
#
# [23249 rows x 1 columns]

# %%
# Scrape wiki site for atari2600 titles
url = 'https://en.wikipedia.org/wiki/List_of_Atari_2600_games'
# Use pandas to read for tables
atari2600_titles = pd.DataFrame(pd.read_html(url)[1]['Atari title'])
atari2600_titles.columns = ['Title']
atari2600_titles
# Out:
#                Title
# 0            32 in 1
# 1    3-D Tic-Tac-Toe
# 2         Action Pak
# 3          Adventure
# 4     Air-Sea Battle
# ..               ...
# 131   Video Olympics
# 132    Video Pinball
# 133         Warlords
# 134        Xenophobe
# 135    Yars' Revenge
#
# [136 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, atari2600_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                             Title
# 0           007: Agent Under Fire
# 1      007: Everything or Nothing
# 2      007: From Russia with Love
# 3                  007: Nightfire
# 4                 187 Ride or Die
# ...                           ...
# 23352              Video Checkers
# 23353                 Video Chess
# 23354              Video Olympics
# 23355               Video Pinball
# 23356                   Xenophobe
#
# [23357 rows x 1 columns]

# %%
# Scrape wiki site for segaGenisis titles
url = 'https://en.wikipedia.org/wiki/List_of_Sega_Genesis_games'
# Use pandas to read for tables
segaGenisis_titles = pd.read_html(url)[1]['Title(s)[12][13][14]']
segaGenisis_titles.columns = ['Title']
segaGenisis_titles
# Out:
#                                   Title
# 0                    3 Ninjas Kick Back
# 1                        688 Attack Sub
# 2                     A Dinosaur's Tale
# 3                   A Ressha de Ikou MD
# 4                Aaahh!!! Real Monsters
# ..                                  ...
# 899       Zhuo Guǐ Dà Shi: Ghost Hunter
# 900  Zombies Ate My NeighborsZombies EU
# 901                                Zool
# 902                               Zoom!
# 903                                Zoop
#
# [904 rows x 1 columns]

# %%
# Concat Titles and Remove Duplicates 
titles = pd.concat([titles, segaGenisis_titles]).drop_duplicates().reset_index(drop=True)
titles
# Out:
#                                     Title
# 0                   007: Agent Under Fire
# 1              007: Everything or Nothing
# 2              007: From Russia with Love
# 3                          007: Nightfire
# 4                         187 Ride or Die
# ...                                   ...
# 23992                           Zero Wing
# 23993       Zhuo Guǐ Dà Shi: Ghost Hunter
# 23994  Zombies Ate My NeighborsZombies EU
# 23995                                Zool
# 23996                               Zoom!
#
# [23997 rows x 1 columns]

# %%
# Remove Bad Title Formats
formatted = []

for i in range(len(titles)):
    sep = '•'
    text = titles.iloc[i]['Title']
    text = text.split(sep, 1)[0]
    sep = '['
    text = text.split(sep, 1)[0]
    sep = '-'
    text = text.split(sep, 1)[0]
    sep = '['
    text = text.split(sep, 1)[0]
    sep = '–'
    text = text.split(sep, 1)[0]
    sep = '('
    text = text.split(sep, 1)[0]
    formatted.append(text)

formatted
# Out:
# ['007: Agent Under Fire',
#  '007: Everything or Nothing',
#  '007: From Russia with Love',
#  '007: Nightfire',
#  '187 Ride or Die',
#  '2002 FIFA World Cup',
#  '25 To Life',
#  '4x4 EVO 2',
#  '50 Cent: Bulletproof',
#  'Advent Rising',
#  'Æon Flux',
#  'AFL Live 2003',
#  'AFL Live 2004',
#  'AFL Live Premiership Edition',
#  'AFL Premiership 2005',
#  'Aggressive Inline',
#  'Airforce Delta Storm Deadly Skies ',
#  'Alias',
#  'Alien Hominid',
#  'Aliens Versus Predator: Extinction',
#  'Alfa Romeo Racing Italiano SCAR\xa0: Squadra Corse Alfa Romeo ',
#  'All',
#  'All',
#  'All',
#  'Alter Echo',
#  "America's Army: Rise of a Soldier",
#  'American Chopper',
#  'American Chopper 2: Full Throttle',
#  'AMF Bowling 2004',
#  'AMF Xtreme Bowling 2006',
#  'Amped: Freestyle Snowboarding',
#  'Amped 2 Tenku 2 ',
#  'AND 1 Streetball',
#  'Angelic Concert ',
#  'Animaniacs: The Great Edgar Hunt',
#  'Antz Extreme Racing',
#  'Aoi Namida ',
#  'APEX Racing Evoluzione ',
# ...

# %%
camelcase_formatted = []
for i in range(len(formatted)):
    text = formatted[i]
    splitted = re.sub('([A-Z][a-z]+)', r' \1', re.sub('([A-Z]+)', r' \1', text)).split()
    camelcase_formatted.append(splitted)
    
camelcase_formatted
# Out:
# [['007:', 'Agent', 'Under', 'Fire'],
#  ['007:', 'Everything', 'or', 'Nothing'],
#  ['007:', 'From', 'Russia', 'with', 'Love'],
#  ['007:', 'Nightfire'],
#  ['187', 'Ride', 'or', 'Die'],
#  ['2002', 'FIFA', 'World', 'Cup'],
#  ['25', 'To', 'Life'],
#  ['4x4', 'EVO', '2'],
#  ['50', 'Cent:', 'Bulletproof'],
#  ['Advent', 'Rising'],
#  ['Æon', 'Flux'],
#  ['AFL', 'Live', '2003'],
#  ['AFL', 'Live', '2004'],
#  ['AFL', 'Live', 'Premiership', 'Edition'],
#  ['AFL', 'Premiership', '2005'],
#  ['Aggressive', 'Inline'],
#  ['Airforce', 'Delta', 'Storm', 'Deadly', 'Skies'],
#  ['Alias'],
#  ['Alien', 'Hominid'],
#  ['Aliens', 'Versus', 'Predator:', 'Extinction'],
#  ['Alfa',
#   'Romeo',
#   'Racing',
#   'Italiano',
#   'SCAR',
#   ':',
#   'Squadra',
#   'Corse',
#   'Alfa',
#   'Romeo'],
#  ['All'],
#  ['All'],
#  ['All'],
#  ['Alter', 'Echo'],
#  ["America's", 'Army:', 'Rise', 'of', 'a', 'Soldier'],
#  ['American', 'Chopper'],
#  ['American', 'Chopper', '2:', 'Full', 'Throttle'],
# ...

# %%
titles_formatted = pd.DataFrame(formatted, columns=['Title'])
titles_formatted = titles_formatted.sort_values('Title').reset_index(drop=True)
titles_formatted = titles_formatted.drop(titles_formatted.index[0:4]).reset_index(drop=True)
titles_formatted
# Out:
#                                    Title
# 0                        #killallzombies
# 1      &: Sora no Mukō de Saki Masuyō ni
# 2                          'Splosion Man
# 3                    'n Verlore Verstand
# 4                                ...Iru!
# ...                                  ...
# 23988                              Ōkami
# 23989                           Ōkami HD
# 23990                           Ōkamiden
# 23991                             Ōokuki
# 23992                       Ōzumō Spirit
#
# [23993 rows x 1 columns]

# %%
# Setup Chromedriver
executable_path = {'executable_path': 'chromedriver/chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
# Scrape data from IGDB for Cloud Database
url = 'https://www.igdb.com/discover'
browser.visit(url)

# %%
# Test Search Input
browser.find_by_id('search').fill(f"{titles_formatted.iloc[0]['Title']} \n")

# %%
first_found = browser.find_by_css('div.game-result').first

# %%
browser.visit(first_found.find_by_css('a')['href'])

# %%
# Genres and Play Mode
info_section_1 = browser.find_by_css('div.optimisly-game-extrainfo1')
genres = []
playMode = []
for block in info_section_1.find_by_css('a.block'):
    if block['itemprop'] == 'playMode':
        print(block.text)
        playMode.append(block.text)
    if block['itemprop'] == 'genre':
        print(block.text)
        genre.append(block.text)
# Out:
# Single player
# Adventure
# Shooter

# %%
# Themes Series and Player Perspectives
info_section_2 = browser.find_by_css('div.optimisly-game-extrainfo2')
themes = []
series = []
playerPerspectives = []
for block in info_section_2.find_by_css('a.block'):
    string = str(block['href'])
    if 'themes' in string:
        print(block.text)
        themes.append(block.text)
    if 'collections' in string:
        print(block.text)
        series.append(block.text)
    if 'perspectives' in string:
        print(block.text)
        playerPerspectives.append(block.text)
# Out:
# Action
# James Bond
# First person

# %%
# Image Link
image = browser.find_by_css('img.img-responsive.cover_big')['src']
image
# Out:
# 'https://images.igdb.com/igdb/image/upload/t_cover_big/co1ot1.jpg'

# %%
# Member Rating
member_rating = browser.find_by_css('text.gauge-description').text
member_rating
# Out:
# 'Fair'

# %%
# Game Description
try:
    browser.find_by_css('div.gamepage-tabs').find_by_css('div')[6].find_by_css('span').click()
    game_description = browser.find_by_css('div.gamepage-tabs').find_by_css('div')[6].text
except:
    game_description = browser.find_by_css('div.gamepage-tabs').find_by_css('div')[6].text
game_description.replace('\n', '').replace('...', '. ')
# Out:
# "James Bond 007: Agent Under Fire is the first James Bond game to appear on the PlayStation 2, GameCube, and Xbox. The game casts the player as the legendary James Bond who must accomplish missions throughout different areas of the world. Bond is sent on a mission rescue Zoe Nightshade, a CIA agent in the hands of Nigel Bloch. Nigel Bloch is the CEO of Identicon, a section of a highly successful industry company known as Malprave industries. Bond is also tasked to retrieve the set of DNA samples that are in Identicon's hands. So James Bond sets off on another adventure.The game combines three game modes into one package: first-person-shooter, which is what most of the missions are, a rail-shooter, where the player only controls firing, and a driving game, where the player drives one of the many Bond cars. Numerous weapons have been added to the series, along with some fictional weapons like the Photon cannon and the 5-way grenade launcher. The player can utilize a wide array of gadge
# ...

# %%
# Keywords
try:
    browser.find_by_css('div.optimisly-game-extrainfo2').find_by_css('div')[3].find_by_css('span').click()
    keywords = browser.find_by_css('div.optimisly-game-extrainfo2').find_by_css('div')[3].text
except:
    keywords = browser.find_by_css('div.optimisly-game-extrainfo2').find_by_css('div')[3].text
keywords.replace(',', '')
# Out:
# '.45 defender 60 fps on consoles agents ak-47 aston martin db5 automated sentry gun auto shotgun barrel bmw z8 body armor bots breast bounce briefcase building bullet colt anaconda crate crosshair cutscene death desert eagle e3 2001 electromagnetic pulse enemy sniper espionage evil organization explosion first-person perspective first person shooter fn p90 games based on movies gloves golden gun government grapple greatest hits gun hand-to-hand combat helicopter boss henchmen h&k g11 id tech 3 instant kill james bond jet pack jump licensed game light up crosshair machine gun machine pistol magnum male protagonists non-player character one-man army on-rails polygonal 3d pp7 rapid fire reloading rocket scope shotgun shotgun shells ski mask smaw spas-12 spies stealth street light submachine gun switch terrorists tie-in train trip mine turret walther ppk weapons swap zoom'

# %%
# Test Scrape Loop for data from IGDB for Cloud Database
url = 'https://www.igdb.com/discover'
browser.visit(url)
import numpy as np
for i in range(len(titles_formatted)):
    data_row = []
    # Search Input
    try:
        browser.find_by_id('search').fill(f"{titles_formatted.iloc[i]['Title']} \n")
        more_info_link = ''
    except:
        continue
    try:
        first_found = browser.find_by_id('search-results').find_by_css('div.game-result').first
        more_info_link = first_found.find_by_css('a')['href']
        data_row.append(more_info_link)
        browser.visit(first_found.find_by_css('a')['href'])
    except:
        data_row.append(more_info_link)
        continue
    time.sleep(1)
    # title
    title = ''
    try:
        title = browser.find_by_css('h1.banner-title').text
        data_row.append(title)    
    except:
        continue
    # Systems
    systems = []
    try: 
        for block in browser.find_by_css('div.gamepage-tabs').find_by_css('a'):
            if 'platforms' in block['href']:
                systems.append(block.text)
        data_row.append(systems)
    except:
        data_row.append(systems)
    # Genres and Play Mode
    try:
        info_section_1 = browser.find_by_css('div.optimisly-game-extrainfo1')
        genres = []
        playMode = []
        for block in info_section_1.find_by_css('a.block'):
            if block['itemprop'] == 'playMode':
                playMode.append(block.text)
            elif block['itemprop'] == 'genre':
                genres.append(block.text)
        data_row.append(genres)
        data_row.append(playMode)
        # Themes Series and Player Perspectives
        info_section_2 = browser.find_by_css('div.optimisly-game-extrainfo2')
        themes = []
        series = ''
        playerPerspectives = []
        for block in info_section_2.find_by_css('a.block'):
            string = str(block['href'])
            if 'themes' in string:
                themes.append(block.text)
            if 'collections' in string:
                series = block.text
            if 'perspectives' in string:
                playerPerspectives.append(block.text)
        data_row.append(themes)
        data_row.append(series)
        data_row.append(playerPerspectives)
    except:
        continue
    # Image Link
    try:
        image = browser.find_by_css('img.img-responsive.cover_big')['src']
        data_row.append(image)
    except:
        continue
    # Member Rating
    try:
        member_rating = browser.find_by_css('text.gauge-description').text
    except:
        continue
    data_row.append(member_rating)
    # Game Description
    try:
        browser.find_by_css('div.gamepage-tabs').find_by_css('div')[6].find_by_css('span').click()
        game_description = browser.find_by_css('div.gamepage-tabs').find_by_css('div')[6].text
    except:
        try:
            game_description = browser.find_by_css('div.gamepage-tabs').find_by_css('div')[6].text
        except:
            continue
    if game_description == 'This game is missing a summary, register an account to add one.':
        continue
    game_description = game_description.replace('\n', '').replace('...', '. ')
    data_row.append(game_description)
    # Keywords
    try:
        browser.find_by_css('div.optimisly-game-extrainfo2').find_by_css('div')[3].find_by_css('span').click()
        keywords = browser.find_by_css('div.optimisly-game-extrainfo2').find_by_css('div')[3].text
    except:
        try:
            keywords = browser.find_by_css('div.optimisly-game-extrainfo2').find_by_css('div')[3].text
        except:
            keywords = ''
    keywords = keywords.replace(',', '')
    data_row.append(keywords)
    # Append Row to DataFrame
    if i == 0:
        test_df = pd.DataFrame(np.reshape(data_row, (1,12)), columns = ['title','moreInfo', 'systems', 'genres',
                                                                        'playModes', 'themes', 'series', 'playerPerspectives',
                                                                        'imageLink', 'memberRating', 'gameDescription',
                                                                        'keywords'])
        
    else:
        df_length = len(test_df)
        test_df.loc[df_length] = data_row
test_df
# Out:
#                           title  \
# 0               #killallzombies
# 1                 'Splosion Man
# 2           'n Verlore Verstand
# 3       .hack//G.U. Last Recode
# 4     .hack//G.U.vol.1//Rebirth
# ...                         ...
# 5629            Puyo Pop: Fever
# 5630                  Puyo Puyo
# 5631                Puyo Puyo 7
# 5632        Puyo Puyo Champions
# 5633          Puyo Puyo Fever 2
#
#                                                moreInfo  \
# 0      https://www.igdb.com/games/number-killallzombies
# 1            https://www.igdb.com/games/ms-splosion-man
# 2         https://www.igdb.com/games/n-verlore-verstand
# 3     https://www.igdb.com/games/dot-hack-slash-slas...
# 4     https://www.igdb.com/games/dot-hack-slash-slas...
# ...                                                 ...
# 5629          https://www.igdb.com/games/puyo-pop-fever
# 5630               https://www.igdb.com/games/puyo-puyo
# 5631             https://www.igdb.com/games/puyo-puyo-7
# ...

# %%
test_df
# Out:
#                                             title  \
# 0                                 #killallzombies
# 1                                   'Splosion Man
# 2                             'n Verlore Verstand
# 3                         .hack//G.U. Last Recode
# 4                       .hack//G.U.vol.1//Rebirth
# ...                                           ...
# 1656                                 Cyber Jansou
# 1657  Cyberdimension Neptunia: 4 Goddesses Online
# 1658                                      Cyberia
# 1659                                   Cybernator
# 1660            CyraidBakuretsu Senshi Warrior JP
#
#                                                moreInfo  \
# 0      https://www.igdb.com/games/number-killallzombies
# 1            https://www.igdb.com/games/ms-splosion-man
# 2         https://www.igdb.com/games/n-verlore-verstand
# 3     https://www.igdb.com/games/dot-hack-slash-slas...
# 4     https://www.igdb.com/games/dot-hack-slash-slas...
# ...

# %%
len(data_row)
# Out:
# 11

# %%
test_df.to_csv('test_df.csv')

# %%
data_row
# Out:
# ["'Splosion Man",
#  'https://www.igdb.com/games/ms-splosion-man',
#  ['iOS',
#   'Xbox Live Arcade',
#   'Windows Phone',
#   'PC (Microsoft Windows)',
#   'Nintendo Switch'],
#  ['iOS',
#   'Xbox Live Arcade',
#   'Windows Phone',
#   'PC (Microsoft Windows)',
#   'Nintendo Switch'],
#  ['iOS',
#   'Xbox Live Arcade',
#   'Windows Phone',
#   'PC (Microsoft Windows)',
#   'Nintendo Switch'],
#  ['iOS',
#   'Xbox Live Arcade',
#   'Windows Phone',
#   'PC (Microsoft Windows)',
#   'Nintendo Switch'],
#  ['iOS',
#   'Xbox Live Arcade',
#   'Windows Phone',
#   'PC (Microsoft Windows)',
#   'Nintendo Switch'],
#  ['Indie', 'Platform'],
#  ['Co-operative', 'Multiplayer', 'Single player'],
#  ['Action', 'Comedy', 'Science fiction'],
#  'Splosion Man',
#  ['Side view'],
#  'https://images.igdb.com/igdb/image/upload/t_cover_big/co27ml.jpg',
#  'Good',
# ...

# %%
test_df
# Out:
#                                                  title  \
# 0                                007: Agent Under Fire
# 1                           007: Everything or Nothing
# 2                           007: From Russia with Love
# 3                                       007: Nightfire
# 4                                  2002 FIFA World Cup
# ..                                                 ...
# 939                          Dragon Ball: Raging Blast
# 940                        Dragon Ball: Raging Blast 2
# 941  Dragon Ball Z: Budokai HD Collection remaster ...
# 942                                     Dragon's Dogma
# 943                        Dragon's Dogma: Dark Arisen
#
#                                                 genres  \
# 0                                 [Adventure, Shooter]
# 1                          [Adventure, Shooter, Sport]
# 2                                    [Racing, Shooter]
# 3                                            [Shooter]
# ...

# %%
for i in range(len(test_df['title'])):
    if 'berzerk' in test_df['title'][i].lower():
        print(test_df['title'][i])
        print(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d84b50d78f89> in <module>
# ----> 1 for i in range(len(test_df['title'])):
#       2     if 'berzerk' in test_df['title'][i].lower():
#       3         print(test_df['title'][i])
#       4         print(i)
#
# NameError: name 'test_df' is not defined
