# %%
import pandas as pd

# %%
# Read in data
data = pd.read_csv('../assets/data/compressed_df.csv').drop('Unnamed: 0', axis=1)
data
# Out:
#                           title  \
# 0       .hack//G.U. Last Recode
# 1                   007 Legends
# 2     James Bond 007: Nightfire
# 3             10 Second Ninja X
# 4                 Silent Hill 2
# ...                         ...
# 3060                         iO
# 3061                 inFAMOUS 2
# 3062       Infamous: Second Son
# 3063                        Pid
# 3064             Treasure Stack
#
#                                                moreInfo             systems  \
# 0     https://www.igdb.com/games/dot-hack-slash-slas...   Eighth Generation
# 1                https://www.igdb.com/games/007-legends  Seventh Generation
# 2     https://www.igdb.com/games/james-bond-007-nigh...    Fifth Generation
# 3          https://www.igdb.com/games/10-second-ninja-x   Eighth Generation
# 4              https://www.igdb.com/games/silent-hill-2    Sixth Generation
# ...                                                 ...                 ...
# ...

# %%
unique_systems = list(data['systems'].unique())
unique_genres = list(data['genres'].unique())
unique_playModes = list(data['playModes'].unique())
unique_themes = list(data['themes'].unique())
unique_series = list(data['series'].unique())
unique_perspective = list(data['playerPerspectives'].unique())
payload = {
    'systems': unique_systems,
    'genres': unique_genres,
    'playModes': unique_playModes,
    'themes': unique_themes,
    'series': unique_series,
    'playerPerspectives': unique_perspective
}
print(payload)
# Out:
# {'systems': ['Eighth Generation', 'Seventh Generation', 'Fifth Generation', 'Sixth Generation', 'Second Generation', 'Third Generation', 'First Generation', 'Fourth Generation'], 'genres': ['Adventure - Role-playing (RPG)', 'Shooter', 'Arcade - Indie - Platform - Puzzle', 'Adventure - Puzzle', 'Adventure - Indie - Platform', 'Fighting - Indie - Sport', 'Indie - Platform - Puzzle - Strategy', nan, 'Arcade - Sport', 'Racing - Sport', 'Adventure', "Adventure - Hack and slash/Beat 'em up - Indie - Shooter", 'Indie - Music - Platform', 'Real Time Strategy (RTS) - Simulator - Strategy', 'Racing', 'Racing - Shooter', 'Adventure - Indie - Role-playing (RPG)', 'Adventure - Indie', 'Arcade - Indie', 'Adventure - Platform', 'Sport', 'Simulator - Sport', 'Adventure - Indie - Point-and-click - Visual Novel', 'Indie - Platform - Shooter', 'Adventure - Shooter', 'Adventure - Indie - Puzzle', 'Adventure - Sport', 'Adventure - Visual Novel', 'Racing - Simulator - Sport', 'Adventure - Role-playing (RP
# ...

# %%
from itertools import groupby
y = [2, 4, 5, 3, 1, 1, 2, 4, 3, 3, 3, 4, 5]
[len(list(group)) for key, group in groupby(sorted(y))]
# Out:
# [2, 2, 4, 3, 2]
